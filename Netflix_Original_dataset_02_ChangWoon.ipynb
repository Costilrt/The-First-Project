# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# Study data files
movie_path = "./netflix_original_movie_data.csv"

movie_df = pd.read_csv(movie_path)

movie_df = movie_df.dropna(axis='columns', how='all')
sort_movies = movie_df.sort_values(by=['Release date.1'], ascending=True)


country = pd.DataFrame(movie_df['Country'].value_counts())
print(sort_movies.columns)
movie_df.dropna(axis='columns', inplace=False, thresh=20)
# Out:
# Index(['Unnamed: 0', 'Title', 'Directed by', 'Produced by', 'Screenplay by',
#        'Based on', 'Starring', 'Music by', 'Cinematography', 'Edited by',
#        'Production companies', 'Distributed by', 'Release date',
#        'Running time', 'Country', 'Language', 'Budget', 'Box office',
#        'Running Time', 'Budget.1', 'Box Office', 'Release date.1',
#        'Written by', 'Production company', 'Story by', 'Narrated by', 'French',
#        'Spanish', 'Italian', 'Portuguese', 'Animation by',
#        'Revised Romanization', 'Literally', 'Turkish', 'Indonesian', 'German',
#        'Norwegian', 'Polish', 'Music', 'Lyrics', 'Book', 'Basis',
#        'Productions'],
#       dtype='object')
#      Unnamed: 0                                             Title  \
# 0             0                               Beasts of No Nation
# 1             1                                  The Ridiculous 6
# 2             2  Crouching Tiger, Hidden Dragon: Sword of Destiny
# ...

# %%
(country.loc[country['Country'] > 5]).plot(kind='bar');
